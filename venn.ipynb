# %%
from matplotlib_venn import venn2
from matplotlib import pyplot as plt
import numpy as np
from matplotlib_venn import venn3, venn3_circles
# %matplotlib inline

# %%
set1 = set(['A', 'B', 'C'])
set2 = set(['B', 'C', 'D', 'E'])
set3 = set(['C', 'D',' E', 'F'])

venn3([set1, set2, set3], ('Set1', 'Set2', 'Set3'))
plt.show()

# %%
set1 = set([1, 2, 3])
set2 = set([2, 3, 4, 5])
set3 = set([3, 4, 5, 6])

venn3([set1, set2, set3], ('Set1', 'Set2', 'Set3'))
plt.show()
# Out:
# /home/ogando/miniconda2/lib/python2.7/site-packages/matplotlib_venn/_venn3.py:117: UserWarning: Bad circle positioning
#   warnings.warn("Bad circle positioning")

# %%
wen = set(['142.5_62_.01', '143.5_62_.01', '144.5.62.01'])
ryk = set(['142.5_62_.01', '143.5.62.01', '145.5.62.01', '146.5.62.01'])
koe = set(['142.5.62.01', 'D',' E', 'F'])


venn3([set1, set2, set3], ('Set1', 'Set2', 'Set3'))
plt.show()

# %%
ra = 142.324653457634765
dec = -62.98723497803452987342
z = 0.2345

# %%
crazyid = '%.1f_%.1f_%.1f'%(ra, dec, z)
print crazyid
# Out:
# 142.3_-63.0_0.2
